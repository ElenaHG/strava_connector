# %%
import os
import pandas as pd
from api_connector.strava_requestor import StravaRequestor

pd.set_option('display.max_columns', None)

# Get the current working directory
current_directory = os.getcwd()

# %%
connection_path = current_directory + '/api_connector/connection.json'
secret_path =  current_directory + '/api_connector/secrets.json'
strava_merger = StravaRequestor(connection_path, secret_path)

# %%
strava_merger.get_last_activities_overview(5)
# Out:
#    resource_state                                 athlete               name  \
# 0               2  {'id': 108251676, 'resource_state': 1}      Oakville Ride
# 1               2  {'id': 108251676, 'resource_state': 1}      NTRC long run
# 2               2  {'id': 108251676, 'resource_state': 1}  Afternoon Workout
# 3               2  {'id': 108251676, 'resource_state': 1}       Growing Grit
# 4               2  {'id': 108251676, 'resource_state': 1}        warm up run
#
#    distance  moving_time  elapsed_time  total_elevation_gain     type  \
# 0  107076.0        14936         22695                 305.1     Ride
# 1   27349.7         9446         14514                 200.5      Run
# 2       0.0         2885          2885                   0.0  Workout
# 3    6341.0         2083          2141                   8.6      Run
# 4    2545.0          768           778                   2.3      Run
#
#   sport_type  workout_type           id            start_date  \
# ...
