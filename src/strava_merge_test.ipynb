# %%
import pandas as pd
pd.set_option('display.max_columns', None)
from api_connector.strava_requestor import StravaActivityMerger

# %%
connection_path = '/Users/elena/Development/Projects/strava_merge_activities/src/api_connector/connection.json'
secret_path = '/Users/elena/Development/Projects/strava_merge_activities/src/api_connector/secrets.json'
strava_merger = StravaActivityMerger(connection_path, secret_path)

# %%
strava_merger.get_last_activities_overview(5)
# Out:
#    resource_state                                 athlete               name  \
# 0               2  {'id': 108251676, 'resource_state': 1}         Lunch Ride
# 1               2  {'id': 108251676, 'resource_state': 1}       Morning Ride
# 2               2  {'id': 108251676, 'resource_state': 1}       Morning Ride
# 3               2  {'id': 108251676, 'resource_state': 1}      NTRC long run
# 4               2  {'id': 108251676, 'resource_state': 1}  Afternoon Workout
#
#    distance  moving_time  elapsed_time  total_elevation_gain     type  \
# 0   44031.9         6650          9131                 149.4     Ride
# 1   23127.0         2926          3799                  41.6     Ride
# 2   36685.4         5073          6305                 107.4     Ride
# 3   27349.7         9446         14514                 200.5      Run
# 4       0.0         2885          2885                   0.0  Workout
#
#   sport_type  workout_type           id            start_date  \
# ...
